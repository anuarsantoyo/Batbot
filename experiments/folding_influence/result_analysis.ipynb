# %%
import pandas as pd
from utils import *
import matplotlib
import matplotlib.pyplot as plt
import plotly.express as px
from tqdm import tqdm
import os
from scipy.signal import savgol_filter
import scipy
plt.rcParams["font.family"] = "DejaVu Serif"
plt.rcParams["font.serif"] = ["Times New Roman"]

# %%
# import required module

# assign directory
directory = 'data/5deg_350motor'
smoothing = True
calibrate = True
if calibrate:
    calib = pd.read_csv('data/calibration.csv').drop('timestamp', axis=1).mean()

sensor_col=[f'sensor_{i}' for i in range(1,7)]

experiments = {}
# that directory
for filename in os.listdir(directory):
    if filename[-3:] == 'csv':
        if 'extended' in filename:
            f = os.path.join(directory, filename)
            experiments[filename] = pd.read_csv(f)
            experiments[filename]['experiment'] = 'extended'
            experiments[filename]['experiment_id'] = int(filename[filename.find('_')+1])

        if 'folding' in filename:
            f = os.path.join(directory, filename)
            experiments[filename] = pd.read_csv(f)
            experiments[filename]['experiment'] = 'folding'
            experiments[filename]['experiment_id'] = int(filename[filename.find('_')+1])
        if smoothing:
            y = experiments[filename][[f'sensor_{i}' for i in range(1,7)]]
            experiments[filename][[f'sensor_{i}' for i in range(1,7)]] = savgol_filter(y, 10, 3, axis=0)
        if calibrate:
            experiments[filename][sensor_col] = experiments[filename][sensor_col] - calib
        experiments[filename][sensor_col] = experiments[filename][sensor_col]*scipy.constants.g
        experiments[filename]['lift'] = experiments[filename]['sensor_4'] + experiments[filename]['sensor_5'] + experiments[filename]['sensor_6']

        experiments[filename]['thrust'] = experiments[filename]['sensor_2'] + experiments[filename]['sensor_3'] - experiments[filename]['sensor_1']


df = pd.concat([experiments[exp] for exp in experiments], ignore_index=True)

# %%
from matplotlib.patches import Rectangle
start_search = {
    1:[4,4.4],
    2:[4.5, 4.4],
    3:[4.3, 4],
    4:[4, 4.4],
    5:[4, 4.4],
    6:[4, 4],
    7:[4.5, 4.4],
    8:[4.3, 4.4]}

input = {
    1:58,
    2:62,
    3:66,
    4:70,
    5:74,
    6:78,
    7:82,
    8:86}

def linestyle(experiment_id):
    if experiment_id< 4:
        return 'solid'
    elif experiment_id<7:
        return 'dashed'
    else:
        return 'dashdot'

plot_id = 1
fig, axs = plt.subplots(3,2, figsize=(13,7))

amp_avg = {}
for col, experiment in enumerate(['extended', 'folding']):
    amp_avg[experiment] = {'mean':[], 'amplitude':[]}

    for row, experiment_id in enumerate([1,4,8]):
        # Slice for one experiment
        df_sliced = df[(df.experiment_id == experiment_id)&(df.experiment == experiment)&(df.timestamp > start_search[experiment_id][col])].copy()

        # Plot the whole lift
        title = round(.5+.04*(experiment_id+1),2)
        axs[row][col].plot(df_sliced.timestamp,df_sliced.lift, label=f'{input[experiment_id]}% input',linestyle=linestyle(experiment_id))
        axs[row][col].set_ylim(-4,6)

        # Find roots and save to know up-downstroke
        rect_start_end = []
        start_not_found = True
        old_sign = 0
        for a in df_sliced.lift.items() :
            new_sign = np.sign(a[1])
            if old_sign*new_sign < 0:
                point = df.iloc[a[0]].timestamp
                rect_start_end.append(point)
                if start_not_found:
                    start = point
                    start_not_found = False
            old_sign = new_sign

        # Plot from first root and change ticks
        axs[row][col].set_xlim(start,start+3)
        xtick_positions = np.linspace(start, start+3, 4)
        xtick_labels = ['0', '1', '2', '3']
        axs[row][col].set_xticks(xtick_positions)
        axs[row][col].set_xticklabels(xtick_labels)

        # Plot rectangles
        for i in range(0,len(rect_start_end[:10]),2):
            start = rect_start_end[i]
            end =rect_start_end[i+1]
            width = end-start
            # Rectangle
            axs[row][col].add_patch(Rectangle((start, -4), width, 10, alpha = 0.25, color='green'))

        # Find average amplitude and mean value
        first = rect_start_end[0]
        i=0
        amplitudes = []
        averages = []
        while (rect_start_end[i+2]-first)<=3:
                start = rect_start_end[i]
                end =rect_start_end[i+2]
                stroke = df_sliced[(start<=df_sliced.timestamp)&(end>=df_sliced.timestamp)].copy()
                amplitudes.append(stroke.lift.max()-stroke.lift.min())
                averages.append(stroke.lift.mean())
                i += 2

        mean = np.array(averages).mean()
        amplitude = np.array(amplitudes).mean()

        amp_avg[experiment]['mean'].append(mean)
        amp_avg[experiment]['amplitude'].append(amplitude)

        # Subplot magic
        if plot_id == 1:
            axs[row][col].set_title('Flapping Motion')
        if plot_id == 4:
            axs[row][col].set_title('Flapping-Folding Motion')

        if plot_id%3==0:
            axs[row][col].set_xlabel('Time (s)')
        axs[row][col].set_ylabel('Lift (N)')
        axs[row][col].legend(loc='upper right')
        plot_id += 1

plt.savefig('data/5deg_350motor/strokes.tif', dpi=600)

# %%
# Import Library

import numpy as np
import matplotlib.pyplot as plt

# Define Data

x = [58, 62, 66, 70, 74, 78, 82, 86]


# Create Plot
fig, ax1 = plt.subplots(1,2, figsize=(17, 5))
#######
data_1 = amp_avg['extended']['amplitude']
data_2 = amp_avg['extended']['mean']

ax1[0].set_xlabel('Input (%)')
ax1[0].set_ylabel('Lift (N)', color = 'blue')
ax1[0].set_ylim(4,8)
plot_1 = ax1[0].plot(x, data_1, marker='o', color = 'blue', label='|M|amp')
ax1[0].tick_params(axis ='y', labelcolor = 'blue')

ax2 = ax1[0].twinx()

ax2.set_ylabel('Lift (N)', color = 'red')
plot_2 = ax2.plot(x, data_2, color = 'red', label='|M|avg')
ax2.set_ylim(0.5,0.9)
ax2.tick_params(axis ='y', labelcolor = 'red')


lns = plot_1 + plot_2
labels = [l.get_label() for l in lns]
plt.legend(lns, labels, loc=0)
######
data_1 = amp_avg['folding']['amplitude']
data_2 = amp_avg['folding']['mean']

ax1[1].set_xlabel('Lift (N)')
ax1[1].set_ylabel('Y1-axis', color = 'blue')
ax1[1].set_ylim(4,8)
plot_1 = ax1[1].plot(x, data_1, color = 'blue', label='|M|amp')
ax1[1].tick_params(axis ='y', labelcolor = 'blue')

ax2 = ax1[1].twinx()

ax2.set_ylabel('Lift (N)', color = 'red')
plot_2 = ax2.plot(x, data_2, color = 'red', label='|M|avg')
ax2.set_ylim(0.5,0.9)
ax2.tick_params(axis ='y', labelcolor = 'red')


lns = plot_1 + plot_2
labels = [l.get_label() for l in lns]
plt.legend(lns, labels, loc=0)

# Show plot
plt.show()

# %%
fig, axs = plt.subplots(1,2, figsize=(13, 5))
calc = ['mean', 'amplitude']
name = {'mean': '|F|avg', 'amplitude': '|F|amp'}
args = {'extended': ['Flapping Motion', 'red', 'o'], 'folding': ['Flapping-Folding Motion', 'blue', '^']}

for i, cal in enumerate(calc):
    for experiment in ['extended', 'folding']:
        axs[i].plot(x,amp_avg[experiment][cal], label=args[experiment][0], marker=args[experiment][2], color=args[experiment][1])

    axs[i].set_title(name[cal])
    axs[i].legend()
    axs[i].set_xlabel('Input (%)')
    axs[i].set_ylabel('Lift (N)')
#fig.show()
fig.savefig('data/5deg_350motor/averages.tif', dpi=600)

# %%
amp_avg[experiment] = {}
first = rect_start_end[0]
i=0
amplitudes = []
averages = []
while (rect_start_end[i+2]-first)<=3:
        start = rect_start_end[i]
        end =rect_start_end[i+2]
        stroke = df_sliced[(start<=df_sliced.timestamp)&(end>=df_sliced.timestamp)].copy()
        plt.plot(stroke.timestamp, stroke.lift)
        amplitudes.append(stroke.lift.max()-stroke.lift.min())
        averages.append(stroke.lift.mean())
        i += 2

mean = np.array(amplitudes).mean()
amplitude = np.array(amplitudes).mean()

amp_avg[experiment]['mean'].append(mean)
amp_avg[experiment]['amplitude'].append(amplitude)
# Out:
# 6.766114543787892 0.8921038318043959

# %%
for experiment_id in range(1,9):
    title = round(.5+.04*(experiment_id+1),2)
    fig = px.line(df[df.experiment_id == experiment_id], x='timestamp', y= 'lift', color='experiment', title=f'% from max: {title}  Volts: {round(title*12,2)}')# y=['thrust', 'lift'])
    fig.show()
# Out:
# <div>                            <div id="3d729fcb-e84e-45a2-b228-db6e9b882378" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3d729fcb-e84e-45a2-b228-db6e9b882378")) {                    Plotly.newPlot(                        "3d729fcb-e84e-45a2-b228-db6e9b882378",                        [{"hovertemplate":"experiment=folding<br>timestamp=%{x}<br>lift=%{y}<extra></extra>","legendgroup":"folding","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"folding","showlegend":true,"x":[0.0,0.0160427093505859,0.0320303440093994,0.0481059551239013,0.0639612674713134,0.0801634788513183,0.0962123870849609,0.1121995449066162,0.1283307075500488,0.1449160575866699,0.1601972579956054,0.1764333248138427,0.1928646564483642,0.2082631587982177,0.2248008251190185,0.2407748699188232,0.2568423748016357,0.2723948955535888,0.2882256507873535,0.3040776252746582,0.3201081752777099,0.3360288143157959,0.352078914642334,0.3681814670562744,0.3842101097106933,0.4004647731781006,0.4168679714202881,0.4323410987854004,0.4483780860900879,0.4642808437347412,0.4801630973815918,0.4967989921569824,0.5127859115600586,0.5282237529754639,0.5442490577697754,0.560250997543335,0.5762455463409424,0.5923163890838623,0.6089069843292236,0.6242039203643799,0.6401383876800537,0.6561660766601562,0.6729860305786133,0.68833327293396,0.7042217254638672,0.7201364040374756,0.7361960411071777,0.7521767616271973,0.768822193145752,0.7843444347381592,0.8003549575805664,0.8166625499725342,0.8322131633758545,0.8481295108795166,0.8648405075073242,0.8802225589752197,0.8962044715881348,0.9122323989868164,0.9281618595123292,0.944765567779541,0.960179090499878,0.9761664867401124,0.9927563667297364,1.0087792873382568,1.0241494178771973,1.040853500366211,1.0563592910766602,1.0729281902313232,1.0888402462005615,1.10416841506958,1.1203279495239258,1.136347770690918,1.152207851409912,1.1682178974151611,1.1842701435089111,1.2002534866333008,1.2161314487457275,1.232231378555298,1.2482812404632568,1.2649543285369873,1.2801992893218994,1.2962117195129397,1.312171459197998,1.328266143798828,1.344785213470459,1.360774040222168,1.376823663711548,1.392242431640625,1.4087858200073242,1.4242374897003174,1.440805435180664,1.4562265872955322,1.472283124923706,1.488269567489624,1.5041463375091553,1.5202038288116455,1.536257028579712,1.5527613162994385,1.5681321620941162,1.5842876434326172,1.6003503799438477,1.6162569522857666,1.632235765457153,1.648387432098389,1.6647939682006836,1.6802620887756348,1.6963233947753906,1.7123205661773682,1.728864669799805,1.7442152500152588,1.7607300281524658,1.7767925262451172,1.7921547889709473,1.8084092140197756,1.82430362701416,1.8404111862182615,1.8564486503601076,1.8725149631500244,1.8883929252624512,1.9044735431671145,1.9204697608947756,1.9369854927062988,1.9529454708099363,1.9683291912078855,1.984854221343994,2.0003879070281982,2.016838312149048,2.032306909561157,2.048178672790528,2.064083337783813,2.080057144165039,2.096134662628174,2.1120967864990234,2.128194093704224,2.144122838973999,2.160233497619629,2.176276922225952,2.192272901535034,2.2080864906311035,2.2245047092437744,2.2407426834106445,2.2561957836151123,2.272803544998169,2.2884204387664795,2.304940700531006,2.320995569229126,2.336967945098877,2.3524458408355717,2.368208885192871,2.384136199951172,2.400071620941162,2.416080951690674,2.432067394256592,2.448075771331787,2.46404767036438,2.4800620079040527,2.4961345195770264,2.5121266841888428,2.5283350944519043,2.544358253479004,2.560396671295166,2.576305389404297,2.5925796031951904,2.608314752578736,2.624333143234253,2.6406471729278564,2.656249046325684,2.672515869140625,2.688502550125122,2.7046420574188232,2.720269203186035,2.736518621444702,2.752261161804199,2.7685513496398926,2.78445 ...
# <div>                            <div id="f2a312aa-8e9c-4e04-ba6d-7ba8b3f3f669" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f2a312aa-8e9c-4e04-ba6d-7ba8b3f3f669")) {                    Plotly.newPlot(                        "f2a312aa-8e9c-4e04-ba6d-7ba8b3f3f669",                        [{"hovertemplate":"experiment=extended<br>timestamp=%{x}<br>lift=%{y}<extra></extra>","legendgroup":"extended","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"extended","showlegend":true,"x":[0.0,0.0159742832183837,0.0321664810180664,0.0482997894287109,0.0641839504241943,0.0801057815551757,0.0962972640991211,0.1120784282684326,0.1283309459686279,0.1441872119903564,0.1602799892425537,0.1763229370117187,0.1922488212585449,0.2081899642944336,0.2241184711456298,0.2401528358459472,0.2561655044555664,0.2723639011383056,0.2880184650421142,0.3039274215698242,0.3199043273925781,0.3359160423278808,0.3519191741943359,0.3680872917175293,0.384000301361084,0.4000957012176513,0.4160029888153076,0.4322471618652344,0.448075532913208,0.4642276763916015,0.4801757335662842,0.4962518215179443,0.5121779441833496,0.5281832218170166,0.5441396236419678,0.5603175163269043,0.5762839317321777,0.5921144485473633,0.6079940795898438,0.6240155696868896,0.6400022506713867,0.6560313701629639,0.6722114086151123,0.6886405944824219,0.704073429107666,0.719994306564331,0.7361645698547363,0.7521286010742188,0.7681725025177002,0.7841010093688965,0.8001909255981445,0.8160643577575684,0.8321897983551025,0.8481957912445068,0.8643004894256592,0.8801460266113281,0.8961431980133057,0.9119985103607178,0.9279940128326416,0.944159746170044,0.9600601196289062,0.9762864112854004,0.992234230041504,1.00834059715271,1.024132251739502,1.0400052070617676,1.0560123920440674,1.0720129013061523,1.088120698928833,1.104275465011597,1.120063066482544,1.13615083694458,1.152672290802002,1.1682236194610596,1.1840598583221436,1.2001819610595703,1.2161741256713867,1.2320778369903564,1.2480244636535645,1.263988018035889,1.2799596786499023,1.29599928855896,1.3120009899139404,1.327986717224121,1.3439998626708984,1.3600261211395264,1.3760497570037842,1.392098903656006,1.408076286315918,1.4241485595703125,1.440112590789795,1.4560961723327637,1.4721837043762207,1.4880077838897705,1.5041077136993408,1.5206480026245115,1.5361711978912354,1.5521135330200195,1.5682291984558103,1.5841069221496582,1.6001853942871094,1.616793155670166,1.6322729587554932,1.6481990814208984,1.6642720699310305,1.6802380084991455,1.6961326599121094,1.7122337818145752,1.7286558151245115,1.7442946434020996,1.760230541229248,1.7761268615722656,1.7922427654266355,1.8082730770111084,1.8241376876831052,1.8402791023254397,1.856226921081543,1.872175931930542,1.888213396072388,1.904122829437256,1.9201011657714844,1.9362356662750244,1.952183961868286,1.968189239501953,1.984192371368408,2.0002150535583496,2.0161924362182617,2.0322883129119877,2.0482964515686035,2.0641677379608154,2.0802605152130127,2.0961029529571533,2.1120641231536865,2.1282780170440674,2.1442947387695312,2.1602141857147217,2.1762847900390625,2.192420959472656,2.20825719833374,2.224240064620972,2.24023985862732,2.256340265274048,2.2722463607788086,2.2882678508758545,2.304210901260376,2.3200151920318604,2.335977792739868,2.351989984512329,2.367992401123047,2.3842945098876958,2.4000747203826904,2.416222333908081,2.4320406913757324,2.448304891586304,2.464071750640869,2.4802732467651367,2.4963033199310303,2.512272834777832,2.5281577110290527,2.544401168823242,2.560328722000122,2.5762033462524414,2.5923428535461426,2.608707904815674,2.624277114868164,2.6402177810668945,2.65624737739563,2.672723293304444,2.688269853591919,2.704270124435425,2.7203257083892822,2.7362990379333496,2.752277135848999,2.76828598976135 ...
# <div>                            <div id="f39ec435-f547-4251-87df-64b8dc59ba41" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f39ec435-f547-4251-87df-64b8dc59ba41")) {                    Plotly.newPlot(                        "f39ec435-f547-4251-87df-64b8dc59ba41",                        [{"hovertemplate":"experiment=extended<br>timestamp=%{x}<br>lift=%{y}<extra></extra>","legendgroup":"extended","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"extended","showlegend":true,"x":[0.0,0.0161552429199218,0.0323209762573242,0.0480790138244628,0.0640530586242675,0.0802257061004638,0.0964870452880859,0.1120882034301757,0.128699779510498,0.1441817283630371,0.1603357791900634,0.176210880279541,0.19236421585083,0.2080543041229248,0.224208116531372,0.2401411533355713,0.2561230659484863,0.2723145484924316,0.2880382537841797,0.3040573596954345,0.319969892501831,0.335928201675415,0.3519659042358398,0.3679330348968506,0.383967638015747,0.4000842571258545,0.4161391258239746,0.4321420192718506,0.4481167793273926,0.4641056060791015,0.4801349639892578,0.4961302280426025,0.5121376514434814,0.5279576778411865,0.5440664291381836,0.5601465702056885,0.5760695934295654,0.5920178890228271,0.6080477237701416,0.6246604919433594,0.6400730609893799,0.6566469669342041,0.6721584796905518,0.6881411075592041,0.7041852474212646,0.7207515239715576,0.7368688583374023,0.7522554397583008,0.7688634395599365,0.7847745418548584,0.800379753112793,0.8168714046478271,0.8328981399536133,0.8481707572937012,0.8641023635864258,0.8803098201751709,0.8967139720916748,0.9120991230010986,0.9282915592193604,0.9441847801208496,0.9601943492889404,0.976367712020874,0.9923055171966552,1.0083110332489014,1.0242295265197754,1.0408692359924316,1.0561895370483398,1.0723145008087158,1.0887384414672852,1.1041336059570312,1.120110273361206,1.1367366313934326,1.1521823406219482,1.168731451034546,1.18455171585083,1.200244665145874,1.216200351715088,1.232238531112671,1.248779296875,1.2648591995239258,1.2802700996398926,1.296821117401123,1.3129260540008545,1.3288755416870115,1.3442745208740234,1.3601553440093994,1.3766281604766846,1.3923113346099854,1.4082655906677246,1.424281120300293,1.440887689590454,1.4561729431152344,1.4722585678100586,1.488614797592163,1.5042014122009275,1.5202522277832031,1.5362935066223145,1.5521984100341797,1.5688743591308594,1.5848639011383057,1.600785732269287,1.6168594360351562,1.632438898086548,1.6488451957702637,1.6648344993591309,1.68088698387146,1.696863889694214,1.712233066558838,1.728348731994629,1.7448382377624512,1.7603578567504885,1.7763080596923828,1.792170524597168,1.8082275390625,1.8248741626739504,1.8408210277557373,1.8561830520629885,1.872258186340332,1.8884177207946775,1.904109001159668,1.9202780723571775,1.936913251876831,1.9521777629852293,1.9683220386505127,1.9846086502075195,2.000871419906616,2.0168566703796387,2.03288197517395,2.048877716064453,2.0645065307617188,2.0803167819976807,2.096822738647461,2.112187623977661,2.1283020973205566,2.144245147705078,2.1607511043548584,2.1762938499450684,2.192370891571045,2.20823335647583,2.224254846572876,2.2408711910247803,2.256207227706909,2.2723190784454346,2.2882912158966064,2.304270029067993,2.320151805877685,2.3368890285491943,2.3521440029144287,2.3682615756988525,2.384875774383545,2.400771379470825,2.416875123977661,2.432898998260498,2.4487874507904053,2.464848279953003,2.48084044456482,2.496877431869507,2.512204647064209,2.52869200706482,2.544851779937744,2.5608696937561035,2.5762951374053955,2.59229040145874,2.6082799434661865,2.624276638031006,2.640476942062378,2.656330347061157,2.672336339950561,2.6882646083831787,2.7042484283447266,2.720160007476806,2.736912488937378,2.752290964126587,2.768956422805786,2.78438830375671 ...
# <div>                            <div id="66a1c07f-6425-4a44-8531-d620d214f916" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("66a1c07f-6425-4a44-8531-d620d214f916")) {                    Plotly.newPlot(                        "66a1c07f-6425-4a44-8531-d620d214f916",                        [{"hovertemplate":"experiment=folding<br>timestamp=%{x}<br>lift=%{y}<extra></extra>","legendgroup":"folding","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"folding","showlegend":true,"x":[0.0,0.016000747680664,0.031982421875,0.0480499267578125,0.0641279220581054,0.0800743103027343,0.0960824489593505,0.1119341850280761,0.128098726272583,0.1442084312438964,0.1600558757781982,0.1761934757232666,0.1927366256713867,0.208223819732666,0.2241730690002441,0.2408187389373779,0.2567839622497558,0.2721304893493652,0.2882022857666015,0.3039991855621338,0.3199646472930908,0.3360788822174072,0.3526647090911865,0.3681139945983886,0.3840689659118652,0.4001259803771972,0.4167733192443847,0.4327726364135742,0.4481618404388428,0.4642713069915771,0.4805459976196289,0.4968276023864746,0.5128827095031738,0.5286979675292969,0.5448486804962158,0.5602626800537109,0.5768258571624756,0.592247486114502,0.6079297065734863,0.6246778964996338,0.6408054828643799,0.6566293239593506,0.6727340221405029,0.6883254051208496,0.7043142318725586,0.7207815647125244,0.7368152141571045,0.7521646022796631,0.7687647342681885,0.7847435474395752,0.8002512454986572,0.8167691230773926,0.8321573734283447,0.8480987548828125,0.864222526550293,0.880476713180542,0.8964254856109619,0.9123952388763428,0.9283535480499268,0.9448142051696776,0.9602394104003906,0.9762132167816162,0.9927663803100586,1.0081117153167725,1.024238348007202,1.040310621261597,1.0568604469299316,1.0723278522491455,1.0883574485778809,1.104153394699097,1.120835304260254,1.136826753616333,1.1522469520568848,1.1688010692596436,1.1848366260528564,1.2002975940704346,1.2167997360229492,1.2326464653015137,1.2481400966644287,1.2648215293884275,1.280864715576172,1.2968571186065674,1.3121941089630127,1.328350305557251,1.344820499420166,1.360227346420288,1.3762719631195068,1.3928143978118896,1.4082980155944824,1.424297332763672,1.4402976036071775,1.4568336009979248,1.472858190536499,1.488851547241211,1.5043926239013672,1.520376682281494,1.5368022918701172,1.5522198677062988,1.5688152313232422,1.5848262310028076,1.6002540588378906,1.6161701679229736,1.632254123687744,1.6481966972351074,1.664215326309204,1.6808369159698486,1.6968209743499756,1.7122650146484375,1.7286992073059082,1.7447853088378906,1.760265588760376,1.776679277420044,1.7928507328033447,1.8082013130187988,1.824848175048828,1.840731143951416,1.856816053390503,1.8728575706481931,1.8888890743255613,1.9042441844940183,1.920870780944824,1.9368507862091064,1.9528007507324217,1.968825340270996,1.9842417240142824,2.0002810955047607,2.01675033569336,2.0328872203826904,2.0482211112976074,2.06418251991272,2.080239534378052,2.0968916416168213,2.112813234329224,2.1288609504699707,2.144836902618408,2.1601898670196533,2.1768081188201904,2.1922807693481445,2.2082905769348145,2.224865436553955,2.2407968044281006,2.2567920684814453,2.272813081741333,2.2888054847717285,2.304835081100464,2.320847749710083,2.336317777633667,2.352272748947144,2.3683180809021,2.3848087787628174,2.400315046310425,2.4168734550476074,2.432858228683472,2.4483323097229004,2.464277744293213,2.4801177978515625,2.4967293739318848,2.5123231410980225,2.5288147926330566,2.544214963912964,2.560262441635132,2.576697587966919,2.5928618907928467,2.6081981658935547,2.624666452407837,2.640822649002075,2.656524658203125,2.672792673110962,2.688821792602539,2.704253673553467,2.720421314239502,2.736860752105713,2.752859354019165,2.7689132690429688,2.78483 ...
# <div>                            <div id="da4c6d7d-73f3-4f31-83a8-ae264853acde" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("da4c6d7d-73f3-4f31-83a8-ae264853acde")) {                    Plotly.newPlot(                        "da4c6d7d-73f3-4f31-83a8-ae264853acde",                        [{"hovertemplate":"experiment=folding<br>timestamp=%{x}<br>lift=%{y}<extra></extra>","legendgroup":"folding","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"folding","showlegend":true,"x":[0.0,0.016099214553833,0.0321254730224609,0.0481770038604736,0.0640103816986084,0.0801913738250732,0.0962357521057128,0.1122891902923584,0.1282272338867187,0.1442265510559082,0.1601002216339111,0.1761801242828369,0.1921031475067138,0.2082505226135254,0.2241394519805908,0.240199327468872,0.2562193870544433,0.2723023891448974,0.2882015705108642,0.3040380477905273,0.319995641708374,0.3360648155212402,0.3520996570587158,0.3681049346923828,0.3841254711151123,0.4001533985137939,0.4161999225616455,0.4320569038391113,0.4483084678649902,0.4643552303314209,0.4803459644317627,0.4962813854217529,0.5122337341308594,0.5283956527709961,0.5443291664123535,0.5603206157684326,0.5762887001037598,0.5921566486358643,0.6083004474639893,0.6242406368255615,0.6403336524963379,0.65610671043396,0.6722226142883301,0.6882731914520264,0.7042849063873291,0.7202095985412598,0.7363176345825195,0.7521657943725586,0.7683413028717041,0.7843761444091797,0.8001973628997803,0.8162992000579834,0.832287073135376,0.8482708930969238,0.8642549514770508,0.8803362846374512,0.8963496685028076,0.9123914241790771,0.9282314777374268,0.9443025588989258,0.9603371620178224,0.9763765335083008,0.9923367500305176,1.00828218460083,1.0243117809295654,1.0403838157653809,1.05625581741333,1.072190761566162,1.0884273052215576,1.104217767715454,1.1203768253326416,1.1363661289215088,1.1522533893585205,1.1682379245758057,1.1843388080596924,1.2002010345458984,1.2163760662078855,1.2323715686798096,1.2483375072479248,1.2643399238586426,1.2803077697753906,1.2962987422943115,1.312347173690796,1.328336238861084,1.3443169593811035,1.36031174659729,1.3764240741729736,1.3923571109771729,1.408259630203247,1.4242451190948486,1.4403533935546875,1.456202745437622,1.4723150730133057,1.4884026050567627,1.5042462348937988,1.5203344821929932,1.5364398956298828,1.5523889064788818,1.5682604312896729,1.584233283996582,1.6002399921417236,1.616410255432129,1.632463455200195,1.6481850147247314,1.6641905307769775,1.6801085472106934,1.6960501670837402,1.7121355533599854,1.7282872200012207,1.74432110786438,1.7603325843811035,1.776240348815918,1.792268991470337,1.8082597255706787,1.824331521987915,1.8403375148773196,1.85625433921814,1.8723852634429927,1.888375997543335,1.904221773147583,1.9201631546020508,1.9361577033996584,1.9520676136016848,1.9683411121368408,1.9841055870056152,2.000282049179077,2.0163044929504395,2.0321404933929443,2.04815411567688,2.064229726791382,2.080307006835937,2.0962793827056885,2.1122069358825684,2.1281445026397705,2.144110679626465,2.1600444316864014,2.1761152744293213,2.1921141147613525,2.2082464694976807,2.2241482734680176,2.240335702896118,2.256253480911255,2.2721784114837646,2.288336038589477,2.304380416870117,2.3203060626983643,2.336463212966919,2.352355718612671,2.3683948516845703,2.3844735622406006,2.4002108573913574,2.4217846393585205,2.4320995807647705,2.4481189250946045,2.464168071746826,2.4800944328308105,2.4960973262786865,2.512082815170288,2.5281896591186523,2.544193983078003,2.5601229667663574,2.576177835464477,2.592147827148437,2.608154296875,2.624070644378662,2.6401350498199463,2.656090021133423,2.672261476516724,2.6882150173187256,2.7042312622070312,2.7202131748199463,2.736231565475464,2.7522072792053223,2.7682301998138428 ...
# <div>                            <div id="b5659fa3-7112-4336-bf8d-58680305b4c1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b5659fa3-7112-4336-bf8d-58680305b4c1")) {                    Plotly.newPlot(                        "b5659fa3-7112-4336-bf8d-58680305b4c1",                        [{"hovertemplate":"experiment=extended<br>timestamp=%{x}<br>lift=%{y}<extra></extra>","legendgroup":"extended","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"extended","showlegend":true,"x":[0.0,0.0161659717559814,0.032123327255249,0.0481269359588623,0.0641288757324218,0.0800333023071289,0.0961260795593261,0.1120307445526123,0.1280174255371093,0.1440186500549316,0.1601860523223877,0.1760194301605224,0.1921768188476562,0.2087104320526123,0.2243688106536865,0.2402009963989257,0.2563686370849609,0.2727694511413574,0.2880580425262451,0.3040547370910644,0.3202667236328125,0.3361179828643799,0.3522369861602783,0.3680973052978515,0.3841350078582763,0.4001140594482422,0.4163632392883301,0.4322614669799804,0.4481854438781738,0.4641342163085937,0.4802925586700439,0.4963560104370117,0.5123939514160156,0.5281553268432617,0.544377326965332,0.56034255027771,0.5767519474029541,0.5921845436096191,0.608184814453125,0.6241223812103271,0.6402955055236816,0.6562199592590332,0.672368049621582,0.6883220672607422,0.7041952610015869,0.7202346324920654,0.736424446105957,0.7522549629211426,0.7681014537811279,0.7842655181884766,0.8002705574035645,0.8165111541748047,0.8323447704315186,0.8483798503875732,0.864173173904419,0.8802957534790039,0.8963608741760254,0.912400722503662,0.928441047668457,0.9448444843292236,0.9604084491729736,0.9762961864471436,0.9922287464141846,1.008192539215088,1.024080514907837,1.0406460762023926,1.0562841892242432,1.0721604824066162,1.0881357192993164,1.10420823097229,1.12030291557312,1.136192798614502,1.1527976989746094,1.168703556060791,1.1847891807556152,1.200221300125122,1.216275930404663,1.2323102951049805,1.248806715011597,1.2647309303283691,1.2801806926727295,1.2968089580535889,1.3123703002929688,1.3282992839813232,1.3446800708770752,1.3602981567382812,1.3768370151519775,1.3924283981323242,1.4083921909332275,1.4242417812347412,1.4403128623962402,1.4562335014343262,1.472292184829712,1.4883825778961182,1.5042343139648438,1.5207626819610596,1.5364148616790771,1.5522956848144531,1.5688188076019287,1.5848701000213623,1.6003105640411377,1.6167240142822266,1.6322097778320312,1.6487932205200195,1.6644346714019775,1.6804418563842771,1.696810245513916,1.7123210430145264,1.7283949851989746,1.7448675632476809,1.7608354091644287,1.7763736248016355,1.792837142944336,1.8081672191619875,1.8242290019989011,1.840245008468628,1.8568437099456787,1.8721990585327148,1.8882744312286377,1.904247045516968,1.9208438396453855,1.936838150024414,1.9523260593414309,1.9688622951507568,1.9842712879180908,2.000436305999756,2.016883373260498,2.032855272293091,2.0487794876098637,2.064833164215088,2.080876588821411,2.0968708992004395,2.1123063564300537,2.12845516204834,2.14479398727417,2.1603217124938965,2.176281452178955,2.19229793548584,2.20825719833374,2.2241756916046143,2.240255832672119,2.256316900253296,2.272207498550415,2.2884111404418945,2.3043081760406494,2.320424318313598,2.3362841606140137,2.352339267730713,2.3682334423065186,2.3842523097991943,2.400353193283081,2.4168238639831543,2.4328863620758057,2.4483609199523926,2.4648525714874268,2.480882406234741,2.4968485832214355,2.512304782867432,2.5284554958343506,2.544434070587158,2.560345411300659,2.576308488845825,2.5929300785064697,2.608261823654175,2.6242616176605225,2.640228748321533,2.656217575073242,2.672297239303589,2.6882872581481934,2.7041475772857666,2.7204740047454834,2.7363440990448,2.7523298263549805,2.7688567638397217, ...
# <div>                            <div id="ee880488-72e2-4c8b-8d40-d0921356920d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ee880488-72e2-4c8b-8d40-d0921356920d")) {                    Plotly.newPlot(                        "ee880488-72e2-4c8b-8d40-d0921356920d",                        [{"hovertemplate":"experiment=folding<br>timestamp=%{x}<br>lift=%{y}<extra></extra>","legendgroup":"folding","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"folding","showlegend":true,"x":[0.0,0.0159604549407959,0.0321230888366699,0.0481340885162353,0.0642206668853759,0.0804107189178466,0.0964133739471435,0.112149953842163,0.1284306049346923,0.1447622776031494,0.1607983112335205,0.1762552261352539,0.1924521923065185,0.2087752819061279,0.2247645854949951,0.2402155399322509,0.2562992572784424,0.2727868556976318,0.2881388664245605,0.3041002750396728,0.3200075626373291,0.3360352516174316,0.3520262241363525,0.3679981231689453,0.3840107917785644,0.3999946117401123,0.4159753322601318,0.4321036338806152,0.4480957984924316,0.4639747142791748,0.4800662994384765,0.4960482120513916,0.5120136737823486,0.5292727947235107,0.5440011024475098,0.5600912570953369,0.5760810375213623,0.5919909477233887,0.6080586910247803,0.6241164207458496,0.6401128768920898,0.6561837196350098,0.6727795600891113,0.6884803771972656,0.7048795223236084,0.7208795547485352,0.7368652820587158,0.7528529167175293,0.7682797908782959,0.7848021984100342,0.8003137111663818,0.8162956237792969,0.8322019577026367,0.8486690521240234,0.8649165630340576,0.880795955657959,0.8968820571899414,0.912832736968994,0.9282588958740234,0.944812536239624,0.960808277130127,0.9761724472045898,0.9928181171417236,1.008183240890503,1.0248079299926758,1.040796995162964,1.056823968887329,1.072808027267456,1.0882415771484375,1.1043436527252195,1.120835304260254,1.1368491649627686,1.1521666049957275,1.1681616306304932,1.1841495037078855,1.200283765792847,1.2168734073638916,1.2323923110961914,1.2481930255889893,1.2648303508758545,1.2808506488800049,1.296828031539917,1.3123464584350586,1.3288323879241943,1.3448362350463867,1.3602545261383057,1.376859426498413,1.3928625583648682,1.4088804721832275,1.424370288848877,1.440370798110962,1.4562056064605713,1.4721806049346924,1.4880390167236328,1.5042603015899658,1.5203089714050293,1.5362529754638672,1.5528898239135742,1.568286418914795,1.5848863124847412,1.6003057956695557,1.6162147521972656,1.6328837871551514,1.6483042240142822,1.6644926071166992,1.6803066730499268,1.6962647438049316,1.7121479511260986,1.728137731552124,1.7441020011901855,1.760694980621338,1.7761201858520508,1.792846918106079,1.8081934452056885,1.824333906173706,1.8403801918029783,1.8568415641784668,1.87219762802124,1.8882627487182615,1.9041826725006104,1.920353651046753,1.9362821578979488,1.9524972438812256,1.9682650566101076,1.9842681884765625,2.000375270843506,2.0162839889526367,2.0321743488311768,2.04836654663086,2.0643019676208496,2.080902099609375,2.0962822437286377,2.112856149673462,2.128861427307129,2.144834518432617,2.1603596210479736,2.176168918609619,2.1923158168792725,2.2088558673858643,2.224274158477783,2.2403464317321777,2.2569003105163574,2.2728922367095947,2.288320302963257,2.304370164871216,2.320326566696167,2.336341857910156,2.352717638015747,2.36833930015564,2.384294271469116,2.400369882583618,2.416323184967041,2.4327492713928223,2.4484033584594727,2.4643499851226807,2.480290174484253,2.4968886375427246,2.5125880241394043,2.528360366821289,2.544248580932617,2.56083083152771,2.5769410133361816,2.592495441436768,2.6083195209503174,2.6242566108703613,2.640221357345581,2.656769037246704,2.6722300052642822,2.6880903244018555,2.704162359237671,2.7203071117401123,2.7364861965179443,2.752354383468628,2.7683718204498 ...
# <div>                            <div id="d44945c9-2e6d-466f-aff7-be884d3dbc11" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d44945c9-2e6d-466f-aff7-be884d3dbc11")) {                    Plotly.newPlot(                        "d44945c9-2e6d-466f-aff7-be884d3dbc11",                        [{"hovertemplate":"experiment=extended<br>timestamp=%{x}<br>lift=%{y}<extra></extra>","legendgroup":"extended","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"extended","showlegend":true,"x":[0.0,0.016108751296997,0.032076358795166,0.048072338104248,0.0641367435455322,0.0800285339355468,0.0962018966674804,0.1119678020477294,0.127979040145874,0.1441383361816406,0.1601359844207763,0.1760826110839843,0.192272663116455,0.2082917690277099,0.2242734432220459,0.2401134967803955,0.2562081813812256,0.2722072601318359,0.2881734371185303,0.304234504699707,0.320258617401123,0.3362035751342773,0.3521304130554199,0.3680927753448486,0.384037971496582,0.3999946117401123,0.4162259101867676,0.4323339462280273,0.448322057723999,0.464148998260498,0.480156660079956,0.4962306022644043,0.5123391151428223,0.5283324718475342,0.5443181991577148,0.5600993633270264,0.5762228965759277,0.592038631439209,0.6079752445220947,0.6241934299468994,0.6403157711029053,0.656364917755127,0.6722960472106934,0.6886739730834961,0.704226016998291,0.7202720642089844,0.7362146377563477,0.7522830963134766,0.768308162689209,0.7842814922332764,0.8001585006713867,0.8161463737487793,0.8322567939758301,0.848334789276123,0.8640797138214111,0.8799648284912109,0.8958652019500732,0.9119572639465332,0.927987813949585,0.9439544677734376,0.960031032562256,0.9760241508483888,0.9921977519989014,1.0080947875976562,1.024309158325195,1.0404131412506104,1.0563271045684814,1.0724895000457764,1.0884149074554443,1.104142189025879,1.1201541423797607,1.1368110179901123,1.1521203517913818,1.168378829956055,1.184295415878296,1.200178623199463,1.216278314590454,1.2322180271148682,1.248290777206421,1.2641878128051758,1.2803637981414795,1.2962186336517334,1.312039852142334,1.3283543586730957,1.3447933197021484,1.3600149154663086,1.376788854598999,1.3922643661499023,1.4087936878204346,1.4243125915527344,1.4407846927642822,1.4563333988189695,1.47237229347229,1.4883430004119873,1.5041518211364746,1.5202817916870115,1.5363168716430664,1.5521142482757568,1.5679917335510254,1.5840027332305908,1.5999391078948977,1.6159851551055908,1.6319327354431152,1.648014783859253,1.6640009880065918,1.679983139038086,1.696134090423584,1.7121167182922363,1.7282702922821045,1.7442634105682373,1.760253667831421,1.7762830257415771,1.792273998260498,1.8082852363586424,1.8242754936218264,1.8403244018554688,1.8561899662017824,1.872246265411377,1.888112545013428,1.9041624069213867,1.9201581478118896,1.936211347579956,1.952143669128418,1.96827244758606,1.984329462051392,2.000189304351806,2.0162668228149414,2.032280445098877,2.0484132766723637,2.0643012523651123,2.0803043842315674,2.096388578414917,2.112801551818848,2.1282222270965576,2.144781351089477,2.160197734832764,2.176307916641236,2.192769765853882,2.2082247734069824,2.2243127822875977,2.2403085231781006,2.256190061569214,2.2722601890563965,2.28824782371521,2.304291248321533,2.320317506790161,2.336323499679565,2.3521833419799805,2.368330955505371,2.384275197982788,2.4001262187957764,2.416333675384521,2.432307243347168,2.4487969875335693,2.4641964435577397,2.4803194999694824,2.4963161945343018,2.51282286643982,2.5283427238464355,2.544233798980713,2.5603363513946533,2.576260089874268,2.592270612716675,2.608217000961304,2.624282121658325,2.640330076217652,2.6562414169311523,2.672315120697021,2.6883175373077397,2.7041831016540527,2.720400094985962,2.7363173961639404,2.752794027328491,2.76824951171875,2.78431653976 ...

# %% [markdown]
# # Analysis folding forces

# %%
fig = px.scatter(df[(df.experiment_id ==8)&(df.experiment=='folding')], x='thrust', y='lift', animation_frame='timestamp')
fig.layout.updatemenus[0].buttons[0].args[1]["frame"]["duration"] = 100
fig.show()

# %%
plt.plot(df[(df.experiment_id ==8)&(df.experiment=='folding')].thrust,df[(df.experiment_id ==8)&(df.experiment=='folding')].lift)
#plt.xlim(-0,0.4)
#plt.ylim(-0.1,0.3)
plt.hlines(0,-10,10)
