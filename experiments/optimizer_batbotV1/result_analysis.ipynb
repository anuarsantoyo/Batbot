# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import plotly.express as px
from utils import  *
from scipy.signal import savgol_filter, find_peaks
import seaborn as sns
import plotly.express as px
import pickle

# %% [markdown]
# # Visualization of results

# %%
results = pd.read_csv('data/230711/test3/results.csv')

# %%
sns.boxplot(results, x='Generation', y='Score')
plt.show()

# %%
sns.lineplot(results, x='Generation', y='Score')
plt.show()

# %%
fig = px.scatter_3d(results, x='Motor', y='Neutral', z='Amplitude', color='Score', )
#fig.write_html('data/230710/results.html')

# %% [markdown]
# # Measurements visualization

# %%
results = pd.read_csv('data/230710/0_4.csv')
px.line(results,x='timestamp',y=sensors_col)

# %%
results = pd.read_csv('data/230711/0_4.csv')
px.line(results,x='timestamp',y=sensors_col)
